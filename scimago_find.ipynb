# %%
import pandas as pd

df = pd.read_csv('scimagojr2019.csv', sep=';')

#search in title
df1 = df.loc[df['Title'].str.contains(r'Robotics', case=False)]
df2 = df.loc[df['Title'].str.contains(r'source', case=False)]

frames = [df1, df2]
df_title = pd.concat(frames)

#only in Q1 and Q2
df3 = df_title.loc[df['SJR Best Quartile'].str.contains(r'Q1')]
df4 = df_title.loc[df['SJR Best Quartile'].str.contains(r'Q2')]

frames = [df3, df4]
result = pd.concat(frames)

result
# Out:
#         Rank  ...                                         Categories
# 264      265  ...  Artificial Intelligence (Q1); Computer Science...
# 565      566  ...  Applied Mathematics (Q1); Artificial Intellige...
# 710      711  ...  Computer Science Applications (Q1); Control an...
# 1335    1336  ...  Artificial Intelligence (Q1); Biophysics (Q1);...
# 1561    1562  ...  Computer Science Applications (Q1); Control an...
# 2019    2020  ...  Artificial Intelligence (Q1); Biomedical Engin...
# 2744    2745  ...  Computer Science Applications (Q1); Control an...
# 4142    4143  ...  Computer Science Applications (Q1); Control an...
# 4294    4295  ...  Computer Science Applications (Q1); Control an...
# 5046    5047  ...              Computer Science (miscellaneous) (Q1)
# 6740    6741  ...                        Mechanical Engineering (Q1)
# 7294    7295  ...  Mechanical Engineering (Q1); Biomedical Engine...
# 8394    8395  ...  Engineering (miscellaneous) (Q1); Artificial I...
# ...
